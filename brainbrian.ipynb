# %%
# The program will run a memorizatio game that shows a 3 x 3 tiles interface. 
# Then the program will randomly choose a tile, in which the user has to choose it. 

import random
import time

# Asks user for their name 
def name():
    print('What is your name?')
    username = input()

    return username 

# Introduces the user to the game by making a story, then asking for them to play the game 
def intro(username):
    print('Welcome ' + username + ' to Tile Madness!')
    print('This game will test your memorization skills!')
    print('Do you have what it takes to beat me?')
    print('Are you smarter than a chimp?')
    print('Yes or No')
    start = input()
    while True:
        if start[0].lower() == 'y':
            print('We will see about that!')
            break
        elif start[0].lower() == 'n':
            print('Where\'s yo confidence!')
            print('Are you smarter than a chimp?')
            print('Yes or No')
            start = input()
        else:
            print('Wrong input, answer as yes or no!')
            start= input()

username = name()
intro(username)

    
# Set tiles to zero

tile1 = 0
tile2 = 0
tile3 = 0
tile4 = 0
tile5 = 0
tile6 = 0
tile7 = 0
tile8 = 0
tile9 = 0

tilelist = [tile1, tile2, tile3, tile4, tile5, tile6, tile7, tile8, tile9]


# Tile Format 

def tileformatexample(tile):
    # This function prints out the tile. The "tiles" are strings that the program chooses.
    
    tile1 = tile[0]
    tile2 = tile[1]
    tile3 = tile[2]
    tile4 = tile[3]
    tile5 = tile[4]
    tile6 = tile[5]
    tile7 = tile[6]
    tile8 = tile[7]
    tile9 = tile[8]
    

    # Shows example of what the tiles look like 
    print('This is the foramt!')
    print('   |   |')
    print(' ' + str(tile1) + ' | ' + str(tile2) + ' | ' + str(tile3))
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + str(tile4) + ' | ' + str(tile5) + ' | ' + str(tile6))
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + str(tile7) + ' | ' + str(tile8) + ' | ' + str(tile9))
    print('   |   |') 

# Starting the game ( ~ Beggining ~ )

# Time functions add after the example format

def gamestart(tile):
    
    print("The game will start now!")
    print("The game will revolve around this 3 by 3 tile")
 
    # Program chooses the one of the tiles
    
    choosenTile = random.choice(tilelist)
    choosenTile += 1
    
    print('   |   |')
    print(' ' + str(tile1) + ' | ' + str(tile2) + ' | ' + str(tile3))
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + str(tile4) + ' | ' + str(tile5) + ' | ' + str(tile6))
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + str(tile7) + ' | ' + str(tile8) + ' | ' + str(tile9))
    print('   |   |')

# %%
choosenTile

# %%
tilelist = [tile1, tile2, tile3, tile4, tile5, tile6, tile7, tile8, tile9]
choosenTile = random.choice(tilelist)

# %%
choosenTile

# %%
# The program will run a memorizatio game that shows a 3 x 3 tiles interface. 
# Then the program will randomly choose a tile, in which the user has to choose it. 

import random
import time

# Asks user for their name 
def name():
    print('What is your name?')
    username = input()

    return username 

# Introduces the user to the game by making a story, then asking for them to play the game 
def intro(username):
    print('Welcome ' + username + ' to Tile Madness!')
    print('This game will test your memorization skills!')
    print('Do you have what it takes to beat me?')
    print('Are you smarter than a chimp?')
    print('Yes or No')
    start = input()
    while True:
        if start[0].lower() == 'y':
            print('We will see about that!')
            break
        elif start[0].lower() == 'n':
            print('Where\'s yo confidence!')
            print('Are you smarter than a chimp?')
            print('Yes or No')
            start = input()
        else:
            print('Wrong input, answer as yes or no!')
            start= input()



    
# Set tiles to zero

tile1 = 0
tile2 = 0
tile3 = 0
tile4 = 0
tile5 = 0
tile6 = 0
tile7 = 0
tile8 = 0
tile9 = 0

tilelist = [tile1, tile2, tile3, tile4, tile5, tile6, tile7, tile8, tile9]


# Tile Format 

def tileformatexample(tile):
    # This function prints out the tile. The "tiles" are strings that the program chooses.
    
    tile1 = tile[0]
    tile2 = tile[1]
    tile3 = tile[2]
    tile4 = tile[3]
    tile5 = tile[4]
    tile6 = tile[5]
    tile7 = tile[6]
    tile8 = tile[7]
    tile9 = tile[8]
    

    # Shows example of what the tiles look like 
    print('   |   |')
    print(' ' + str(tilelist[0]) + ' | ' + str(tilelist[1]) + ' | ' + str(tilelist[2]))
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + str(tilelist[3]) + ' | ' + str(tilelist[4]) + ' | ' + str(tilelist[5]))
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + str(tilelist[6]) + ' | ' + str(tilelist[7]) + ' | ' + str(tilelist[8]))
    print('   |   |')    

# Starting the game ( ~ Beggining ~ )

# Time functions add after the example format

def gamestart(tile):
    global tilelist
    print("The game will start now!")
    print("The game will revolve around this 3 by 3 tile")
 
    # Program chooses the one of the tiles
    
    chosenTileIdx = random.randrange(len(tilelist))
    tilelist[chosenTileIdx] += 1 
    tileformatexample(tilelist)
    return chosenTileIdx

def chooseTile(tile):
    global tilelist
 
    # Program chooses the one of the tiles
    
    chosenTileIdx = random.randrange(len(tilelist))
    tilelist[chosenTileIdx] += 1 
    tileformatexample(tilelist)
    return chosenTileIdx



    
def userchoose():
    print('Choose a tile! (1-9)')
    userinput = int(input())
    return userinput

def userchooseagain():
    returnArray = []
    print('Choose the tiles in correct sequence of order, seperate them using a space')
    userinput = input()
    userinputs = userinput.split()
    for uinput in userinputs:
        uinput = int(uinput)
        returnArray.append(uinput)
    return returnArray





while True: 
    correct = True
    correctArray = []
    userArray = []
    username = name()
    intro(username)
    correctArray.append(gamestart(tilelist))
    userinput = userchoose()
    
    while correct:
        print(userinput, correctArray[-1], "debugging purposes")

        if userinput - 1 == correctArray[-1]:
            print("Good Job!")
            userArray.append(userinput)
            
        
        else:
            print("You are dumber than a chimp")
            correct = False
        
        
        useranswers = userchooseagain()
        if useranswers == correctArray:
            print("GJ")
# Out:
# What is your name?
# r
# Welcome r to Tile Madness!
# This game will test your memorization skills!
# Do you have what it takes to beat me?
# Are you smarter than a chimp?
# Yes or No
# yes
# We will see about that!
# The game will start now!
# The game will revolve around this 3 by 3 tile
#    |   |
#  0 | 0 | 1
#    |   |
# -----------
#    |   |
#  0 | 0 | 0
#    |   |
# -----------
#    |   |
#  0 | 0 | 0
#    |   |
# Choose a tile! (1-9)
# 3
# 3 2 debugging purposes
# Good Job!
# Choose the tiles in correct sequence of order, seperate them using a space

# %%
while True:
    playerinput = input('Choose a tile! (1-9)')
    try:
        playerinput = int(playerinput)
        if playerinput in range(1, 10):
            break
    except ValueError:
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-79e133ec518b> in <module>
#       1 while True:
# ----> 2     playerinput = input('Choose a tile! (1-9)')
#       3     try:
#       4         playerinput = int(playerinput)
#       5         if playerinput in range(1, 10):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
